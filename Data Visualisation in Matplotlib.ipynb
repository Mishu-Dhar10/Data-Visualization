# %%
import matplotlib.pyplot as plt
fig, ax = plt.subplots()
plt.show()

# %%
import pandas as pd
import plotly.express as px
import seaborn as sns
import plotly.graph_objects as go
import numpy as np
seattle_weather = pd.read_csv('/Users/mishudhar/Downloads/matplotlib and statistics course/seattle_weather.csv')

# %%
seattle_weather.head(15)
# Out:
#         STATION                                 NAME  DATE  MLY-CLDD-BASE45  \
# 0   USC00456295                  PALMER 3 ESE, WA US     1             13.0
# 1   USC00456295                  PALMER 3 ESE, WA US     2             23.0
# 2   USC00456295                  PALMER 3 ESE, WA US     3             50.0
# 3   USC00456295                  PALMER 3 ESE, WA US     4            108.0
# 4   USC00456295                  PALMER 3 ESE, WA US     5            255.0
# 5   USC00456295                  PALMER 3 ESE, WA US     6            384.0
# 6   USC00456295                  PALMER 3 ESE, WA US     7            553.0
# 7   USC00456295                  PALMER 3 ESE, WA US     8            573.0
# 8   USC00456295                  PALMER 3 ESE, WA US     9            417.0
# 9   USC00456295                  PALMER 3 ESE, WA US    10            189.0
# 10  USC00456295                  PALMER 3 ESE, WA US    11             43.0
# 11  USC00456295                  PALMER 3 ESE, WA US    12              6.0
# 12  USW00024222  EVERETT SNOHOMISH CO AIRPORT, WA US     1             26.0
# 13  USW00024222  EVERETT SNOHOMISH CO AIRPORT, WA US     2             25.0
# 14  USW00024222  EVERETT SNOHOMISH CO AIRPORT, WA US     3             72.0
#
#     MLY-CLDD-BASE50  MLY-CLDD-BASE55  MLY-CLDD-BASE57  MLY-CLDD-BASE60  \
# 0               1.0          -7777.0              0.0              0.0
# 1               3.0          -7777.0          -7777.0              0.0
# 2              11.0              1.0          -7777.0          -7777.0
# 3              40.0             12.0              7.0              3.0
# 4             130.0             56.0             38.0             19.0
# 5             237.0            115.0             80.0             45.0
# 6             398.0            246.0            190.0            118.0
# 7             418.0            265.0            206.0            130.0
# 8             270.0            142.0            102.0             57.0
# 9              81.0             25.0             15.0              5.0
# 10              9.0              1.0          -7777.0          -7777.0
# 11          -7777.0          -7777.0          -7777.0              0.0
# 12              4.0          -7777.0              0.0              0.0
# 13              2.0          -7777.0          -7777.0              0.0
# 14             16.0              2.0              1.0          -7777.0
#
#     MLY-CLDD-BASE70  MLY-CLDD-BASE72  ...  MLY-TMIN-AVGNDS-LSTH060  \
# 0               0.0              0.0  ...                    310.0
# 1               0.0              0.0  ...                    280.0
# 2               0.0              0.0  ...                    310.0
# 3           -7777.0              0.0  ...                    300.0
# 4               1.0          -7777.0  ...                    310.0
# 5               3.0              1.0  ...                    299.0
# 6              10.0              5.0  ...                    305.0
# 7               9.0              5.0  ...                    304.0
# 8               3.0              1.0  ...                    298.0
# 9           -7777.0          -7777.0  ...                    310.0
# 10              0.0              0.0  ...                    300.0
# 11              0.0              0.0  ...                    310.0
# 12              0.0              0.0  ...                    310.0
# 13              0.0              0.0  ...                    280.0
# 14              0.0              0.0  ...                    310.0
#
#     MLY-TMIN-AVGNDS-LSTH070  MLY-TMIN-NORMAL  MLY-TMIN-PRBOCC-LSTH016  \
# 0                     310.0             34.0                    168.0
# 1                     280.0             33.9                    132.0
# 2                     310.0             35.9                      5.0
# 3                     300.0             38.3                      0.0
# 4                     310.0             43.5                      0.0
# 5                     300.0             48.0                      0.0
# 6                     310.0             51.9                      0.0
# 7                     310.0             52.4                      0.0
# 8                     300.0             48.6                      0.0
# 9                     310.0             42.6                      0.0
# 10                    300.0             37.1                     20.0
# 11                    310.0             32.6                    162.0
# 12                    310.0             37.0                     81.0
# 13                    280.0             37.2                     19.0
# 14                    310.0             39.6                      0.0
#
#     MLY-TMIN-PRBOCC-LSTH020  MLY-TMIN-PRBOCC-LSTH024  MLY-TMIN-PRBOCC-LSTH028  \
# 0                     327.0                    615.0                    877.0
# 1                     275.0                    515.0                    800.0
# 2                      47.0                    111.0                    393.0
# 3                       0.0                      5.0                    123.0
# 4                       0.0                      0.0                      0.0
# 5                       0.0                      0.0                      0.0
# 6                       0.0                      0.0                      0.0
# 7                       0.0                      0.0                      0.0
# 8                       0.0                      0.0                      0.0
# 9                       0.0                      0.0                     36.0
# 10                     59.0                    175.0                    452.0
# 11                    296.0                    527.0                    848.0
# 12                    183.0                    398.0                    730.0
# 13                     79.0                    246.0                    561.0
# 14                     15.0                     52.0                    181.0
#
#     MLY-TMIN-PRBOCC-LSTH032  MLY-TMIN-PRBOCC-LSTH036  MLY-TMIN-STDDEV
# 0                     987.0                   1000.0              2.8
# 1                     963.0                   1000.0              3.1
# 2                     848.0                   1000.0              2.1
# 3                     571.0                    978.0              2.0
# 4                      83.0                    610.0              2.0
# 5                       0.0                     36.0              1.8
# 6                       0.0                      0.0              1.7
# 7                       0.0                      0.0              1.4
# 8                       4.0                     79.0              1.9
# 9                     323.0                    815.0              1.8
# 10                    811.0                    984.0              3.4
# 11                    990.0                   1000.0              3.0
# 12                    959.0                    999.0              2.9
# 13                    873.0                    994.0              3.0
# 14                    616.0                    977.0              2.0
#
# [15 rows x 80 columns]

# %%
temp = list(np.random.randint(42, 70, size = 12))

# %%
Seatt_weather = pd.DataFrame({'Month':['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec'],
                'Month_avg_temp':temp})
Seatt_weather.head()
# Out:
#   Month  Month_avg_temp
# 0   Jan              65
# 1   Feb              62
# 2   Mar              45
# 3   Apr              49
# 4   May              65

# %%
np.random.seed(42)
random_temp = np.random.randint(42, 70, size = 12)
temp_list = list(random_temp)
austin_weather = pd.DataFrame({'Month':['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec'],
                 'month_avg_temp': temp_list})
austin_weather.head()
# Out:
#   Month  month_avg_temp
# 0   Jan              48
# 1   Feb              61
# 2   Mar              56
# 3   Apr              52
# 4   May              49

# %%
fig, ax = plt.subplots()
#ax.plot(Seatt_weather["Month"], Seatt_weather["Month_avg_temp"], linestyle = "None", marker = 'v')
ax.plot(austin_weather['Month'], austin_weather['month_avg_temp'])
plt.show()

# %%
type(Seatt_weather)
# Out:
# pandas.core.frame.DataFrame

# %%
fig = px.line(Seatt_weather, x = "Month", y = "Month_avg_temp")
fig.show()
# Out:
# <div>                            <div id="0eac53b7-a58a-49ad-b479-7f5963b630d1" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("0eac53b7-a58a-49ad-b479-7f5963b630d1")) {                    Plotly.newPlot(                        "0eac53b7-a58a-49ad-b479-7f5963b630d1",                        [{"hovertemplate":"Month=%{x}<br>Month_avg_temp=%{y}<extra></extra>","legendgroup":"","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"","orientation":"v","showlegend":false,"x":["Jan","Feb","Mar","Apr","May","Jun","Jul","Aug","Sep","Oct","Nov","Dec"],"xaxis":"x","y":[65,62,45,49,65,44,63,62,43,65,53,47],"yaxis":"y","type":"scatter"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"scattergeo":[{"type":"scattergeo","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolar":[{"ty ...

# %%
import plotly.graph_objects as go
import numpy as np

# Generate some random data
x = np.linspace(0, 10, 100)
y1 = np.sin(x)
y2 = np.cos(x)

# Create trace objects for both lines
trace1 = go.Scatter(x=x, y=y1, mode='lines', name='Sine')
trace2 = go.Scatter(x=x, y=y2, mode='lines', name='Cosine')

# Add both trace objects to a data list
data = [trace1, trace2]

# Set the layout of the plot
layout = go.Layout(title='Sine and Cosine Waves', xaxis_title='x', yaxis_title='y')

# Create a Figure object that contains the data and layout
fig = go.Figure(data=data, layout=layout)

# Show the plot
fig.show()
# Out:
# <div>                            <div id="6aa4e320-7be5-4771-a3ac-83edf9b6058e" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("6aa4e320-7be5-4771-a3ac-83edf9b6058e")) {                    Plotly.newPlot(                        "6aa4e320-7be5-4771-a3ac-83edf9b6058e",                        [{"mode":"lines","name":"Sine","x":[0.0,0.10101010101010101,0.20202020202020202,0.30303030303030304,0.40404040404040403,0.5050505050505051,0.6060606060606061,0.7070707070707071,0.8080808080808081,0.9090909090909091,1.0101010101010102,1.1111111111111112,1.2121212121212122,1.3131313131313131,1.4141414141414141,1.5151515151515151,1.6161616161616161,1.7171717171717171,1.8181818181818181,1.9191919191919191,2.0202020202020203,2.121212121212121,2.2222222222222223,2.323232323232323,2.4242424242424243,2.525252525252525,2.6262626262626263,2.727272727272727,2.8282828282828283,2.929292929292929,3.0303030303030303,3.131313131313131,3.2323232323232323,3.3333333333333335,3.4343434343434343,3.5353535353535355,3.6363636363636362,3.7373737373737375,3.8383838383838382,3.9393939393939394,4.040404040404041,4.141414141414141,4.242424242424242,4.343434343434343,4.444444444444445,4.545454545454545,4.646464646464646,4.747474747474747,4.848484848484849,4.94949494949495,5.05050505050505,5.151515151515151,5.252525252525253,5.353535353535354,5.454545454545454,5.555555555555555,5.656565656565657,5.757575757575758,5.858585858585858,5.959595959595959,6.0606060606060606,6.161616161616162,6.262626262626262,6.363636363636363,6.4646464646464645,6.565656565656566,6.666666666666667,6.767676767676767,6.8686868686868685,6.96969696969697,7.070707070707071,7.171717171717171,7.2727272727272725,7.373737373737374,7.474747474747475,7.575757575757575,7.6767676767676765,7.777777777777778,7.878787878787879,7.979797979797979,8.080808080808081,8.181818181818182,8.282828282828282,8.383838383838384,8.484848484848484,8.585858585858587,8.686868686868687,8.787878787878787,8.88888888888889,8.98989898989899,9.09090909090909,9.191919191919192,9.292929292929292,9.393939393939394,9.494949494949495,9.595959595959595,9.696969696969697,9.797979797979798,9.8989898989899,10.0],"y":[0.0,0.1008384202581046,0.2006488565226854,0.2984138044476411,0.3931366121483298,0.48385164043793466,0.5696341069089657,0.6496095135057065,0.7229625614794604,0.7889454628442574,0.8468855636029834,0.8961922010299563,0.9363627251042848,0.9669876227092996,0.9877546923600838,0.9984522269003895,0.9989711717233568,0.9893062365143401,0.9695559491823237,0.9399216514301312,0.9007054462029555,0.8523071179396753,0.7952200570230491,0.7300262299764464,0.6573902466827755,0.5780525851065732,0.4928220425889235,0.40256749066949654,0.30820901749007684,0.2107085480771929,0.11106003812412972,0.010279341240534697,-0.09060614703340773,-0.19056796287548539,-0.28858705872043244,-0.38366419180611233,-0.4748301108222395,-0.5611554368152017,-0.6417601376193878,-0.7158224992291902,-0.7825875026542022,-0.8413745208608701,-0.8915842573351402,-0.9327048555318336,-0.9643171169287783,-0.9860987744909296,-0.9978277779792126,-0.9993845576124357,-0.9907532430056771,-0.9720218249588334,-0.9433812584459996,-0.9051235159501367,-0.8576386109880517,-0.8014106221689697,-0.7370127583189134,-0.6651015149788224,-0.586409981847235,-0.5017403693939113,-0.4119558308308628,-0.31797166281061867,-0.22074597455506337,-0.12126992053716677,-0.020557596287260064,0.08036429967028173,0.18046693235991093,0.2787298186775573,0.37415123057121996,0.4657584070256517,0.5526174707464059,0.6338429484489058,0.7086067976992182,0.7761468482835805,0.8357745720522589,0.8868821020290788,0.9289484292312513,0.9615447140268235,0.9843386578838236,0.9970978909438748,0.9996923408861117,0.9920955589323228,0.9743849894755358,0.9467411805833543,0.9094459434244626,0.862879479 ...

# %%
seattle_weather.shape
# Out:
# (204, 80)

# %%
Austin_weather = pd.read_csv('/Users/mishudhar/Downloads/matplotlib and statistics course/austin_weather.csv')
Austin_weather.shape
# Out:
# (12, 67)

# %%
# Slicing the dataset for 12 month
d_1 = seattle_weather.head(12)

# %% [markdown]
# # adding new column as a month
# month_list =  ['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec']
# new_series = pd.Series(month_list)
# #d_1['Month'] = new_series
# new_series

# %%
d_1
# Out:
#         STATION                 NAME  DATE  MLY-CLDD-BASE45  MLY-CLDD-BASE50  \
# 0   USC00456295  PALMER 3 ESE, WA US     1             13.0              1.0
# 1   USC00456295  PALMER 3 ESE, WA US     2             23.0              3.0
# 2   USC00456295  PALMER 3 ESE, WA US     3             50.0             11.0
# 3   USC00456295  PALMER 3 ESE, WA US     4            108.0             40.0
# 4   USC00456295  PALMER 3 ESE, WA US     5            255.0            130.0
# 5   USC00456295  PALMER 3 ESE, WA US     6            384.0            237.0
# 6   USC00456295  PALMER 3 ESE, WA US     7            553.0            398.0
# 7   USC00456295  PALMER 3 ESE, WA US     8            573.0            418.0
# 8   USC00456295  PALMER 3 ESE, WA US     9            417.0            270.0
# 9   USC00456295  PALMER 3 ESE, WA US    10            189.0             81.0
# 10  USC00456295  PALMER 3 ESE, WA US    11             43.0              9.0
# 11  USC00456295  PALMER 3 ESE, WA US    12              6.0          -7777.0
#
#     MLY-CLDD-BASE55  MLY-CLDD-BASE57  MLY-CLDD-BASE60  MLY-CLDD-BASE70  \
# 0           -7777.0              0.0              0.0              0.0
# 1           -7777.0          -7777.0              0.0              0.0
# 2               1.0          -7777.0          -7777.0              0.0
# 3              12.0              7.0              3.0          -7777.0
# 4              56.0             38.0             19.0              1.0
# 5             115.0             80.0             45.0              3.0
# 6             246.0            190.0            118.0             10.0
# 7             265.0            206.0            130.0              9.0
# 8             142.0            102.0             57.0              3.0
# 9              25.0             15.0              5.0          -7777.0
# 10              1.0          -7777.0          -7777.0              0.0
# 11          -7777.0          -7777.0              0.0              0.0
#
#     MLY-CLDD-BASE72  ...  MLY-TMIN-AVGNDS-LSTH060  MLY-TMIN-AVGNDS-LSTH070  \
# 0               0.0  ...                    310.0                    310.0
# 1               0.0  ...                    280.0                    280.0
# 2               0.0  ...                    310.0                    310.0
# 3               0.0  ...                    300.0                    300.0
# 4           -7777.0  ...                    310.0                    310.0
# 5               1.0  ...                    299.0                    300.0
# 6               5.0  ...                    305.0                    310.0
# 7               5.0  ...                    304.0                    310.0
# 8               1.0  ...                    298.0                    300.0
# 9           -7777.0  ...                    310.0                    310.0
# 10              0.0  ...                    300.0                    300.0
# 11              0.0  ...                    310.0                    310.0
#
#     MLY-TMIN-NORMAL  MLY-TMIN-PRBOCC-LSTH016  MLY-TMIN-PRBOCC-LSTH020  \
# 0              34.0                    168.0                    327.0
# 1              33.9                    132.0                    275.0
# 2              35.9                      5.0                     47.0
# 3              38.3                      0.0                      0.0
# 4              43.5                      0.0                      0.0
# 5              48.0                      0.0                      0.0
# 6              51.9                      0.0                      0.0
# 7              52.4                      0.0                      0.0
# 8              48.6                      0.0                      0.0
# 9              42.6                      0.0                      0.0
# 10             37.1                     20.0                     59.0
# 11             32.6                    162.0                    296.0
#
#     MLY-TMIN-PRBOCC-LSTH024  MLY-TMIN-PRBOCC-LSTH028  MLY-TMIN-PRBOCC-LSTH032  \
# 0                     615.0                    877.0                    987.0
# 1                     515.0                    800.0                    963.0
# 2                     111.0                    393.0                    848.0
# 3                       5.0                    123.0                    571.0
# 4                       0.0                      0.0                     83.0
# 5                       0.0                      0.0                      0.0
# 6                       0.0                      0.0                      0.0
# 7                       0.0                      0.0                      0.0
# 8                       0.0                      0.0                      4.0
# 9                       0.0                     36.0                    323.0
# 10                    175.0                    452.0                    811.0
# 11                    527.0                    848.0                    990.0
#
#     MLY-TMIN-PRBOCC-LSTH036  MLY-TMIN-STDDEV
# 0                    1000.0              2.8
# 1                    1000.0              3.1
# 2                    1000.0              2.1
# 3                     978.0              2.0
# 4                     610.0              2.0
# 5                      36.0              1.8
# 6                       0.0              1.7
# 7                       0.0              1.4
# 8                      79.0              1.9
# 9                     815.0              1.8
# 10                    984.0              3.4
# 11                   1000.0              3.0
#
# [12 rows x 80 columns]

# %%
Austin_weather
# Out:
#         STATION                                           NAME  DATE  \
# 0   USW00013904  AUSTIN BERGSTROM INTERNATIONAL AIRPORT, TX US     1
# 1   USW00013904  AUSTIN BERGSTROM INTERNATIONAL AIRPORT, TX US     2
# 2   USW00013904  AUSTIN BERGSTROM INTERNATIONAL AIRPORT, TX US     3
# 3   USW00013904  AUSTIN BERGSTROM INTERNATIONAL AIRPORT, TX US     4
# 4   USW00013904  AUSTIN BERGSTROM INTERNATIONAL AIRPORT, TX US     5
# 5   USW00013904  AUSTIN BERGSTROM INTERNATIONAL AIRPORT, TX US     6
# 6   USW00013904  AUSTIN BERGSTROM INTERNATIONAL AIRPORT, TX US     7
# 7   USW00013904  AUSTIN BERGSTROM INTERNATIONAL AIRPORT, TX US     8
# 8   USW00013904  AUSTIN BERGSTROM INTERNATIONAL AIRPORT, TX US     9
# 9   USW00013904  AUSTIN BERGSTROM INTERNATIONAL AIRPORT, TX US    10
# 10  USW00013904  AUSTIN BERGSTROM INTERNATIONAL AIRPORT, TX US    11
# 11  USW00013904  AUSTIN BERGSTROM INTERNATIONAL AIRPORT, TX US    12
#
#     MLY-CLDD-BASE45  MLY-CLDD-BASE50  MLY-CLDD-BASE55  MLY-CLDD-BASE57  \
# 0               190              103               50               35
# 1               228              132               68               49
# 2               446              306              185              146
# 3               668              519              373              318
# 4               936              781              626              564
# 5              1081              931              781              721
# 6              1192             1037              882              820
# 7              1199             1044              889              827
# 8               985              835              685              625
# 9               745              591              438              379
# 10              412              281              172              136
# 11              208              119               63               47
#
#     MLY-CLDD-BASE60  MLY-CLDD-BASE70  MLY-CLDD-BASE72  ...  \
# 0                18                1            -7777  ...
# 1                29                3                1  ...
# 2                98               13                6  ...
# 3               240               53               32  ...
# 4               471              181              134  ...
# 5               631              331              272  ...
# 6               727              417              355  ...
# 7               735              425              363  ...
# 8               536              246              193  ...
# 9               295               83               56  ...
# 10               91               12                7  ...
# 11               29                2                1  ...
#
#     MLY-TMIN-AVGNDS-LSTH060  MLY-TMIN-AVGNDS-LSTH070  MLY-TMIN-NORMAL  \
# 0                       302                      310             36.3
# 1                       264                      280             39.4
# 2                       270                      308             46.6
# 3                       193                      287             54.7
# 4                        89                      250             63.7
# 5                         5                      158             69.9
# 6                         0                       83             71.7
# 7                         2                       92             71.3
# 8                        57                      226             65.3
# 9                       199                      284             55.9
# 10                      269                      297             45.5
# 11                      300                      309             37.2
#
#     MLY-TMIN-PRBOCC-LSTH016  MLY-TMIN-PRBOCC-LSTH020  MLY-TMIN-PRBOCC-LSTH024  \
# 0                       298                      570                      839
# 1                       103                      327                      614
# 2                        10                       73                      242
# 3                         0                        0                        0
# 4                         0                        0                        0
# 5                         0                        0                        0
# 6                         0                        0                        0
# 7                         0                        0                        0
# 8                         0                        0                        0
# 9                         0                        0                        3
# 10                        2                       46                      216
# 11                      246                      499                      777
#
#     MLY-TMIN-PRBOCC-LSTH028  MLY-TMIN-PRBOCC-LSTH032  MLY-TMIN-PRBOCC-LSTH036  \
# 0                       967                      997                     1000
# 1                       867                      973                      999
# 2                       494                      761                      928
# 3                        48                      189                      453
# 4                         0                        0                        0
# 5                         0                        0                        0
# 6                         0                        0                        0
# 7                         0                        0                        0
# 8                         0                        0                        0
# 9                        25                       96                      264
# 10                      530                      819                      969
# 11                      941                      991                      999
#
#     MLY-TMIN-STDDEV
# 0               2.9
# 1               3.2
# 2               3.6
# 3               4.1
# 4               2.5
# 5               1.9
# 6               1.3
# 7               1.4
# 8               2.5
# 9               3.7
# 10              2.9
# 11              4.0
#
# [12 rows x 67 columns]

# %%
fig, ax = plt.subplots()
ax.plot(d_1["Month"], d_1["MLY-PRCP-NORMAL"])
ax.plot(Austin_weather["Month"], Austin_weather["MLY-PRCP-NORMAL"])
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /opt/anaconda3/lib/python3.9/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3628             try:
# -> 3629                 return self._engine.get_loc(casted_key)
#    3630             except KeyError as err:
#
# /opt/anaconda3/lib/python3.9/site-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# /opt/anaconda3/lib/python3.9/site-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Month'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# /var/folders/41/5qy4wjjs2fv7xjzw2hgjt1vc0000gn/T/ipykernel_40183/3886995533.py in <module>
#       1 fig, ax = plt.subplots()
# ----> 2 ax.plot(d_1["Month"], d_1["MLY-PRCP-NORMAL"])
#       3 ax.plot(Austin_weather["Month"], Austin_weather["MLY-PRCP-NORMAL"])
#       4 plt.show()
#
# /opt/anaconda3/lib/python3.9/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    3503             if self.columns.nlevels > 1:
#    3504                 return self._getitem_multilevel(key)
# -> 3505             indexer = self.columns.get_loc(key)
#    3506             if is_integer(indexer):
#    3507                 indexer = [indexer]
#
# /opt/anaconda3/lib/python3.9/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3629                 return self._engine.get_loc(casted_key)
#    3630             except KeyError as err:
# -> 3631                 raise KeyError(key) from err
#    3632             except TypeError:
#    3633                 # If we have a listlike key, _check_indexing_error will raise
#
# KeyError: 'Month'

# %% [markdown]
# # Customizing the plots

# %%
fig, ax = plt.subplots()
ax.plot(Seatt_weather["Month"], Seatt_weather["Month_avg_temp"], marker = "o") # circle markere
ax.plot(austin_weather['Month'], austin_weather['month_avg_temp'], marker = "v", linestyle = "--",
       color = 'r') # Triangle mamrker
plt.show() # Notice the line stylef

# %%
fig, ax = plt.subplots()
ax.plot(Seatt_weather["Month"], Seatt_weather["Month_avg_temp"], marker = "o") # circle markere
ax.plot(austin_weather['Month'], austin_weather['month_avg_temp'], marker = "v") # Triangle mamrker
ax.set_xlabel("Time(months)")
ax.set_ylabel("Temperature(Farenhite)")
ax.set_title("Weather in Seattle and Austin")
plt.show()

# %% [markdown]
# # Samll multiples

# %%
fig, ax = plt.subplots(3,2)
plt.show()
ax.shape
# Out:
# (3, 2)

# %%
fig, ax = plt.subplots(3,2, sharey = True)

ax[0, 0].plot(d_1["Month"], d_1["MLY-PRCP-NORMAL"])
ax[1,1].plot(Austin_weather["Month"], Austin_weather["MLY-PRCP-NORMAL"])

plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /opt/anaconda3/lib/python3.9/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3628             try:
# -> 3629                 return self._engine.get_loc(casted_key)
#    3630             except KeyError as err:
#
# /opt/anaconda3/lib/python3.9/site-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# /opt/anaconda3/lib/python3.9/site-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Month'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# /var/folders/41/5qy4wjjs2fv7xjzw2hgjt1vc0000gn/T/ipykernel_40183/125587673.py in <module>
#       1 fig, ax = plt.subplots(3,2, sharey = True)
#       2
# ----> 3 ax[0, 0].plot(d_1["Month"], d_1["MLY-PRCP-NORMAL"])
#       4 ax[1,1].plot(Austin_weather["Month"], Austin_weather["MLY-PRCP-NORMAL"])
#       5
#
# /opt/anaconda3/lib/python3.9/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    3503             if self.columns.nlevels > 1:
#    3504                 return self._getitem_multilevel(key)
# -> 3505             indexer = self.columns.get_loc(key)
#    3506             if is_integer(indexer):
#    3507                 indexer = [indexer]
#
# /opt/anaconda3/lib/python3.9/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3629                 return self._engine.get_loc(casted_key)
#    3630             except KeyError as err:
# -> 3631                 raise KeyError(key) from err
#    3632             except TypeError:
#    3633                 # If we have a listlike key, _check_indexing_error will raise
#
# KeyError: 'Month'

# %%
fig, ax = plt.subplots(2,1, sharey = True) # for same range of y axes value
ax[0].plot(d_1["Month"], d_1["MLY-PRCP-NORMAL"], color = 'b')
ax[0].plot(d_1["Month"], d_1["MLY-PRCP-25PCTL"], linestyle = "--", color = 'b')
ax[0].plot(d_1["Month"], d_1["MLY-PRCP-75PCTL"], linestyle = "--", color = 'b')
ax[1].plot(Austin_weather["Month"], Austin_weather["MLY-PRCP-NORMAL"], color = 'r')
ax[1].plot(Austin_weather["Month"], Austin_weather["MLY-PRCP-25PCTL"], linestyle = "--", color = 'r')
ax[1].plot(Austin_weather["Month"], Austin_weather["MLY-PRCP-75PCTL"], linestyle = "--", color = 'r')
ax[0].set_ylabel("Percipitation (inches)")
ax[1].set_ylabel("Percipitation (inches)")

ax[1].set_xlabel("Time (months)")

plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /opt/anaconda3/lib/python3.9/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3628             try:
# -> 3629                 return self._engine.get_loc(casted_key)
#    3630             except KeyError as err:
#
# /opt/anaconda3/lib/python3.9/site-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# /opt/anaconda3/lib/python3.9/site-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Month'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# /var/folders/41/5qy4wjjs2fv7xjzw2hgjt1vc0000gn/T/ipykernel_40183/706354875.py in <module>
#       1 fig, ax = plt.subplots(2,1, sharey = True) # for same range of y axes value
# ----> 2 ax[0].plot(d_1["Month"], d_1["MLY-PRCP-NORMAL"], color = 'b')
#       3 ax[0].plot(d_1["Month"], d_1["MLY-PRCP-25PCTL"], linestyle = "--", color = 'b')
#       4 ax[0].plot(d_1["Month"], d_1["MLY-PRCP-75PCTL"], linestyle = "--", color = 'b')
#       5 ax[1].plot(Austin_weather["Month"], Austin_weather["MLY-PRCP-NORMAL"], color = 'r')
#
# /opt/anaconda3/lib/python3.9/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    3503             if self.columns.nlevels > 1:
#    3504                 return self._getitem_multilevel(key)
# -> 3505             indexer = self.columns.get_loc(key)
#    3506             if is_integer(indexer):
#    3507                 indexer = [indexer]
#
# /opt/anaconda3/lib/python3.9/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3629                 return self._engine.get_loc(casted_key)
#    3630             except KeyError as err:
# -> 3631                 raise KeyError(key) from err
#    3632             except TypeError:
#    3633                 # If we have a listlike key, _check_indexing_error will raise
#
# KeyError: 'Month'

# %%
climate = pd.read_csv('/Users/mishudhar/Downloads/climate_change.csv')
climate.head()
# Out:
#          date     co2  relative_temp
# 0  1958-03-06  315.71           0.10
# 1  1958-04-06  317.45           0.01
# 2  1958-05-06  317.50           0.08
# 3  1958-06-06     NaN          -0.05
# 4  1958-07-06  315.86           0.06

# %%
climate.index
# Out:
# RangeIndex(start=0, stop=706, step=1)

# %%
fig, ax = plt.subplots()
ax.plot(climate.index, climate['co2'])
ax.set_xlabel('Time')
ax.set_ylabel('CO2 (ppm)')
plt.show()

# %%
fig = px.line(climate, x = 'date', y = 'co2')
fig.show()
# Out:
# <div>                            <div id="cfb30ab1-4549-4475-872e-c2f42931f971" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("cfb30ab1-4549-4475-872e-c2f42931f971")) {                    Plotly.newPlot(                        "cfb30ab1-4549-4475-872e-c2f42931f971",                        [{"hovertemplate":"date=%{x}<br>co2=%{y}<extra></extra>","legendgroup":"","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"","orientation":"v","showlegend":false,"x":["1958-03-06","1958-04-06","1958-05-06","1958-06-06","1958-07-06","1958-08-06","1958-09-06","1958-10-06","1958-11-06","1958-12-06","1959-01-06","1959-02-06","1959-03-06","1959-04-06","1959-05-06","1959-06-06","1959-07-06","1959-08-06","1959-09-06","1959-10-06","1959-11-06","1959-12-06","1960-01-06","1960-02-06","1960-03-06","1960-04-06","1960-05-06","1960-06-06","1960-07-06","1960-08-06","1960-09-06","1960-10-06","1960-11-06","1960-12-06","1961-01-06","1961-02-06","1961-03-06","1961-04-06","1961-05-06","1961-06-06","1961-07-06","1961-08-06","1961-09-06","1961-10-06","1961-11-06","1961-12-06","1962-01-06","1962-02-06","1962-03-06","1962-04-06","1962-05-06","1962-06-06","1962-07-06","1962-08-06","1962-09-06","1962-10-06","1962-11-06","1962-12-06","1963-01-06","1963-02-06","1963-03-06","1963-04-06","1963-05-06","1963-06-06","1963-07-06","1963-08-06","1963-09-06","1963-10-06","1963-11-06","1963-12-06","1964-01-06","1964-02-06","1964-03-06","1964-04-06","1964-05-06","1964-06-06","1964-07-06","1964-08-06","1964-09-06","1964-10-06","1964-11-06","1964-12-06","1965-01-06","1965-02-06","1965-03-06","1965-04-06","1965-05-06","1965-06-06","1965-07-06","1965-08-06","1965-09-06","1965-10-06","1965-11-06","1965-12-06","1966-01-06","1966-02-06","1966-03-06","1966-04-06","1966-05-06","1966-06-06","1966-07-06","1966-08-06","1966-09-06","1966-10-06","1966-11-06","1966-12-06","1967-01-06","1967-02-06","1967-03-06","1967-04-06","1967-05-06","1967-06-06","1967-07-06","1967-08-06","1967-09-06","1967-10-06","1967-11-06","1967-12-06","1968-01-06","1968-02-06","1968-03-06","1968-04-06","1968-05-06","1968-06-06","1968-07-06","1968-08-06","1968-09-06","1968-10-06","1968-11-06","1968-12-06","1969-01-06","1969-02-06","1969-03-06","1969-04-06","1969-05-06","1969-06-06","1969-07-06","1969-08-06","1969-09-06","1969-10-06","1969-11-06","1969-12-06","1970-01-06","1970-02-06","1970-03-06","1970-04-06","1970-05-06","1970-06-06","1970-07-06","1970-08-06","1970-09-06","1970-10-06","1970-11-06","1970-12-06","1971-01-06","1971-02-06","1971-03-06","1971-04-06","1971-05-06","1971-06-06","1971-07-06","1971-08-06","1971-09-06","1971-10-06","1971-11-06","1971-12-06","1972-01-06","1972-02-06","1972-03-06","1972-04-06","1972-05-06","1972-06-06","1972-07-06","1972-08-06","1972-09-06","1972-10-06","1972-11-06","1972-12-06","1973-01-06","1973-02-06","1973-03-06","1973-04-06","1973-05-06","1973-06-06","1973-07-06","1973-08-06","1973-09-06","1973-10-06","1973-11-06","1973-12-06","1974-01-06","1974-02-06","1974-03-06","1974-04-06","1974-05-06","1974-06-06","1974-07-06","1974-08-06","1974-09-06","1974-10-06","1974-11-06","1974-12-06","1975-01-06","1975-02-06","1975-03-06","1975-04-06","1975-05-06","1975-06-06","1975-07-06","1975-08-06","1975-09-06","1975-10-06","1975-11-06","1975-12-06","1976-01-06","1976-02-06","1976-03-06","1976-04-06","1976-05-06","1976-06-06","1976-07-06","1976-08-06","1976-09-06","1976-10-06","1976-11-06","1976-12-06","1977-01-06","1977-02-06","1977-03-06","1977-04-06","1977-05-06","1977-06-06","1977-07-06","1977-08-06","1977-09-06","1977-10-06","1977-11-06","1977-12-06","1978-01-06","1978-02-06","1978-03-06","1978-04-06","1978-05-06","1978-06-06","1978-07-06","1978-08-06","1978-09-06","1978-10-06","1978-11-06","1978-12-06","1979-01 ...

# %%
Climate_change = pd.read_csv('/Users/mishudhar/Downloads/climate_change.csv', index_col = [0])
Climate_change.head()
# Out:
#                co2  relative_temp
# date
# 1958-03-06  315.71           0.10
# 1958-04-06  317.45           0.01
# 1958-05-06  317.50           0.08
# 1958-06-06     NaN          -0.05
# 1958-07-06  315.86           0.06

# %%
Climate_change.index
# Out:
# Index(['1958-03-06', '1958-04-06', '1958-05-06', '1958-06-06', '1958-07-06',
#        '1958-08-06', '1958-09-06', '1958-10-06', '1958-11-06', '1958-12-06',
#        ...
#        '2016-03-06', '2016-04-06', '2016-05-06', '2016-06-06', '2016-07-06',
#        '2016-08-06', '2016-09-06', '2016-10-06', '2016-11-06', '2016-12-06'],
#       dtype='object', name='date', length=706)

# %%
fig, ax = plt.subplots()
ax.plot(Climate_change.index, Climate_change['co2'])
ax.set_xlabel('Time')
ax.set_ylabel('CO2 (ppm)')
plt.show()

# %%
# Converting date into datettime format from object
klimat = pd.read_csv('/Users/mishudhar/Downloads/climate_change.csv')
klimat['date'] = pd.to_datetime(klimat['date'])

klimat.head()
# Out:
#         date     co2  relative_temp
# 0 1958-03-06  315.71           0.10
# 1 1958-04-06  317.45           0.01
# 2 1958-05-06  317.50           0.08
# 3 1958-06-06     NaN          -0.05
# 4 1958-07-06  315.86           0.06

# %%
klimat.set_index('date', inplace = True)
klimat.head()
# Out:
#                co2  relative_temp
# date
# 1958-03-06  315.71           0.10
# 1958-04-06  317.45           0.01
# 1958-05-06  317.50           0.08
# 1958-06-06     NaN          -0.05
# 1958-07-06  315.86           0.06

# %%
klimat.index
# Out:
# DatetimeIndex(['1958-03-06', '1958-04-06', '1958-05-06', '1958-06-06',
#                '1958-07-06', '1958-08-06', '1958-09-06', '1958-10-06',
#                '1958-11-06', '1958-12-06',
#                ...
#                '2016-03-06', '2016-04-06', '2016-05-06', '2016-06-06',
#                '2016-07-06', '2016-08-06', '2016-09-06', '2016-10-06',
#                '2016-11-06', '2016-12-06'],
#               dtype='datetime64[ns]', name='date', length=706, freq=None)

# %%
fig, ax = plt.subplots()
ax.plot(klimat.index, klimat['co2'])
ax.set_xlabel('Time')
ax.set_ylabel('CO2 (ppm)')
plt.show()

# %%
# Slicing the dataset for one decade
sixties = klimat["1960-01-01":"1969-12-31"]
fig, ax = plt.subplots()
ax.plot(sixties.index, sixties['co2'])
ax.set_xlabel('Time')
ax.set_ylabel('CO2 (ppm)')
plt.show()

# %%
sixty_nine = klimat["1969-01-01":"1969-12-31"]
fig, ax = plt.subplots()
ax.plot(sixty_nine.index, sixty_nine['co2'])
ax.set_xlabel('Time')
ax.set_ylabel('CO2 (ppm)')
plt.show()

# %%
# A better approach to importing data and converting date to datetime
Climate = pd.read_csv('/Users/mishudhar/Downloads/climate_change.csv', parse_dates = True, index_col = 'date')
Climate.head()
# Out:
#                co2  relative_temp
# date
# 1958-03-06  315.71           0.10
# 1958-04-06  317.45           0.01
# 1958-05-06  317.50           0.08
# 1958-06-06     NaN          -0.05
# 1958-07-06  315.86           0.06

# %%
Climate.index
# Out:
# DatetimeIndex(['1958-03-06', '1958-04-06', '1958-05-06', '1958-06-06',
#                '1958-07-06', '1958-08-06', '1958-09-06', '1958-10-06',
#                '1958-11-06', '1958-12-06',
#                ...
#                '2016-03-06', '2016-04-06', '2016-05-06', '2016-06-06',
#                '2016-07-06', '2016-08-06', '2016-09-06', '2016-10-06',
#                '2016-11-06', '2016-12-06'],
#               dtype='datetime64[ns]', name='date', length=706, freq=None)

# %%
fig = px.line(Climate, x = Climate.index, y = 'relative_temp', title = 'Relative Temp. Over The Years')
fig.show()
# Out:
# <div>                            <div id="93e8f755-65ab-47b3-81d5-b7a2aae67d71" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("93e8f755-65ab-47b3-81d5-b7a2aae67d71")) {                    Plotly.newPlot(                        "93e8f755-65ab-47b3-81d5-b7a2aae67d71",                        [{"hovertemplate":"date=%{x}<br>relative_temp=%{y}<extra></extra>","legendgroup":"","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"","orientation":"v","showlegend":false,"x":["1958-03-06T00:00:00","1958-04-06T00:00:00","1958-05-06T00:00:00","1958-06-06T00:00:00","1958-07-06T00:00:00","1958-08-06T00:00:00","1958-09-06T00:00:00","1958-10-06T00:00:00","1958-11-06T00:00:00","1958-12-06T00:00:00","1959-01-06T00:00:00","1959-02-06T00:00:00","1959-03-06T00:00:00","1959-04-06T00:00:00","1959-05-06T00:00:00","1959-06-06T00:00:00","1959-07-06T00:00:00","1959-08-06T00:00:00","1959-09-06T00:00:00","1959-10-06T00:00:00","1959-11-06T00:00:00","1959-12-06T00:00:00","1960-01-06T00:00:00","1960-02-06T00:00:00","1960-03-06T00:00:00","1960-04-06T00:00:00","1960-05-06T00:00:00","1960-06-06T00:00:00","1960-07-06T00:00:00","1960-08-06T00:00:00","1960-09-06T00:00:00","1960-10-06T00:00:00","1960-11-06T00:00:00","1960-12-06T00:00:00","1961-01-06T00:00:00","1961-02-06T00:00:00","1961-03-06T00:00:00","1961-04-06T00:00:00","1961-05-06T00:00:00","1961-06-06T00:00:00","1961-07-06T00:00:00","1961-08-06T00:00:00","1961-09-06T00:00:00","1961-10-06T00:00:00","1961-11-06T00:00:00","1961-12-06T00:00:00","1962-01-06T00:00:00","1962-02-06T00:00:00","1962-03-06T00:00:00","1962-04-06T00:00:00","1962-05-06T00:00:00","1962-06-06T00:00:00","1962-07-06T00:00:00","1962-08-06T00:00:00","1962-09-06T00:00:00","1962-10-06T00:00:00","1962-11-06T00:00:00","1962-12-06T00:00:00","1963-01-06T00:00:00","1963-02-06T00:00:00","1963-03-06T00:00:00","1963-04-06T00:00:00","1963-05-06T00:00:00","1963-06-06T00:00:00","1963-07-06T00:00:00","1963-08-06T00:00:00","1963-09-06T00:00:00","1963-10-06T00:00:00","1963-11-06T00:00:00","1963-12-06T00:00:00","1964-01-06T00:00:00","1964-02-06T00:00:00","1964-03-06T00:00:00","1964-04-06T00:00:00","1964-05-06T00:00:00","1964-06-06T00:00:00","1964-07-06T00:00:00","1964-08-06T00:00:00","1964-09-06T00:00:00","1964-10-06T00:00:00","1964-11-06T00:00:00","1964-12-06T00:00:00","1965-01-06T00:00:00","1965-02-06T00:00:00","1965-03-06T00:00:00","1965-04-06T00:00:00","1965-05-06T00:00:00","1965-06-06T00:00:00","1965-07-06T00:00:00","1965-08-06T00:00:00","1965-09-06T00:00:00","1965-10-06T00:00:00","1965-11-06T00:00:00","1965-12-06T00:00:00","1966-01-06T00:00:00","1966-02-06T00:00:00","1966-03-06T00:00:00","1966-04-06T00:00:00","1966-05-06T00:00:00","1966-06-06T00:00:00","1966-07-06T00:00:00","1966-08-06T00:00:00","1966-09-06T00:00:00","1966-10-06T00:00:00","1966-11-06T00:00:00","1966-12-06T00:00:00","1967-01-06T00:00:00","1967-02-06T00:00:00","1967-03-06T00:00:00","1967-04-06T00:00:00","1967-05-06T00:00:00","1967-06-06T00:00:00","1967-07-06T00:00:00","1967-08-06T00:00:00","1967-09-06T00:00:00","1967-10-06T00:00:00","1967-11-06T00:00:00","1967-12-06T00:00:00","1968-01-06T00:00:00","1968-02-06T00:00:00","1968-03-06T00:00:00","1968-04-06T00:00:00","1968-05-06T00:00:00","1968-06-06T00:00:00","1968-07-06T00:00:00","1968-08-06T00:00:00","1968-09-06T00:00:00","1968-10-06T00:00:00","1968-11-06T00:00:00","1968-12-06T00:00:00","1969-01-06T00:00:00","1969-02-06T00:00:00","1969-03-06T00:00:00","1969-04-06T00:00:00","1969-05-06T00:00:00","1969-06-06T00:00:00","1969-07-06T00:00:00","1969-08-06T00:00:00","1969-09-06T00:00:00","1969-10-06T00:00:00","1969-11-06T00:00:00","1969-12-06T00:00:00","1970-01-06T00:00:00","1970-02-06T00:00:00","1970-03-06T00:00:00","1970-04-06T00:00:00","1970-05-06T00:00:00","1970-06-06T00 ...

# %%
Ninties = Climate["1990-01-01":"1999-12-31"]
fig = px.line(data_frame = Ninties, x = Ninties.index, y='co2')
fig.show()
# Out:
# <div>                            <div id="64bb538b-c348-4db9-9de0-424b1ddbf0c0" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("64bb538b-c348-4db9-9de0-424b1ddbf0c0")) {                    Plotly.newPlot(                        "64bb538b-c348-4db9-9de0-424b1ddbf0c0",                        [{"hovertemplate":"date=%{x}<br>co2=%{y}<extra></extra>","legendgroup":"","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"","orientation":"v","showlegend":false,"x":["1990-01-06T00:00:00","1990-02-06T00:00:00","1990-03-06T00:00:00","1990-04-06T00:00:00","1990-05-06T00:00:00","1990-06-06T00:00:00","1990-07-06T00:00:00","1990-08-06T00:00:00","1990-09-06T00:00:00","1990-10-06T00:00:00","1990-11-06T00:00:00","1990-12-06T00:00:00","1991-01-06T00:00:00","1991-02-06T00:00:00","1991-03-06T00:00:00","1991-04-06T00:00:00","1991-05-06T00:00:00","1991-06-06T00:00:00","1991-07-06T00:00:00","1991-08-06T00:00:00","1991-09-06T00:00:00","1991-10-06T00:00:00","1991-11-06T00:00:00","1991-12-06T00:00:00","1992-01-06T00:00:00","1992-02-06T00:00:00","1992-03-06T00:00:00","1992-04-06T00:00:00","1992-05-06T00:00:00","1992-06-06T00:00:00","1992-07-06T00:00:00","1992-08-06T00:00:00","1992-09-06T00:00:00","1992-10-06T00:00:00","1992-11-06T00:00:00","1992-12-06T00:00:00","1993-01-06T00:00:00","1993-02-06T00:00:00","1993-03-06T00:00:00","1993-04-06T00:00:00","1993-05-06T00:00:00","1993-06-06T00:00:00","1993-07-06T00:00:00","1993-08-06T00:00:00","1993-09-06T00:00:00","1993-10-06T00:00:00","1993-11-06T00:00:00","1993-12-06T00:00:00","1994-01-06T00:00:00","1994-02-06T00:00:00","1994-03-06T00:00:00","1994-04-06T00:00:00","1994-05-06T00:00:00","1994-06-06T00:00:00","1994-07-06T00:00:00","1994-08-06T00:00:00","1994-09-06T00:00:00","1994-10-06T00:00:00","1994-11-06T00:00:00","1994-12-06T00:00:00","1995-01-06T00:00:00","1995-02-06T00:00:00","1995-03-06T00:00:00","1995-04-06T00:00:00","1995-05-06T00:00:00","1995-06-06T00:00:00","1995-07-06T00:00:00","1995-08-06T00:00:00","1995-09-06T00:00:00","1995-10-06T00:00:00","1995-11-06T00:00:00","1995-12-06T00:00:00","1996-01-06T00:00:00","1996-02-06T00:00:00","1996-03-06T00:00:00","1996-04-06T00:00:00","1996-05-06T00:00:00","1996-06-06T00:00:00","1996-07-06T00:00:00","1996-08-06T00:00:00","1996-09-06T00:00:00","1996-10-06T00:00:00","1996-11-06T00:00:00","1996-12-06T00:00:00","1997-01-06T00:00:00","1997-02-06T00:00:00","1997-03-06T00:00:00","1997-04-06T00:00:00","1997-05-06T00:00:00","1997-06-06T00:00:00","1997-07-06T00:00:00","1997-08-06T00:00:00","1997-09-06T00:00:00","1997-10-06T00:00:00","1997-11-06T00:00:00","1997-12-06T00:00:00","1998-01-06T00:00:00","1998-02-06T00:00:00","1998-03-06T00:00:00","1998-04-06T00:00:00","1998-05-06T00:00:00","1998-06-06T00:00:00","1998-07-06T00:00:00","1998-08-06T00:00:00","1998-09-06T00:00:00","1998-10-06T00:00:00","1998-11-06T00:00:00","1998-12-06T00:00:00","1999-01-06T00:00:00","1999-02-06T00:00:00","1999-03-06T00:00:00","1999-04-06T00:00:00","1999-05-06T00:00:00","1999-06-06T00:00:00","1999-07-06T00:00:00","1999-08-06T00:00:00","1999-09-06T00:00:00","1999-10-06T00:00:00","1999-11-06T00:00:00","1999-12-06T00:00:00"],"xaxis":"x","y":[353.8,355.04,355.73,356.32,357.32,356.34,354.84,353.01,351.31,351.62,353.07,354.33,354.84,355.73,357.23,358.66,359.13,358.13,356.19,353.85,352.25,352.35,353.81,355.12,356.25,357.11,357.86,359.09,359.59,359.33,357.01,354.94,352.96,353.32,354.32,355.57,357.0,357.31,358.47,359.27,360.19,359.52,357.33,355.64,354.03,354.12,355.41,356.91,358.24,358.92,359.99,361.23,361.65,360.81,359.38,357.46,355.73,356.07,357.53,358.98,359.92,360.86,361.83,363.3,363.69,363.19,361.64,359.12,358.17,357.99,359.45,360.68,362.07,363.24,364.17,364.57,365.13,364.92,363.55,361.38,359.54,359.58,360.89,362.24,363.09,364.03,3 ...

# %% [markdown]
# # Plotting time series with different variable

# %%
fig, ax = plt.subplots()
ax.plot(Climate.index, Climate['co2'])
ax.plot(Climate.index, Climate['relative_temp'])
ax.set_xlabel('Time')
ax.set_ylabel('CO2 (ppm) / Relative temperature')
plt.show()

# %% [markdown]
# # Comment- because the unit of the measurments are not the same. To overcome this situation

# %%
fig, ax = plt.subplots()
ax.plot(Climate.index, Climate['co2'], color = 'blue')
ax.set_xlabel('Time')
ax.set_ylabel('CO2 (ppm)', color = 'blue')

#  Creating a twin
ax2 = ax.twinx()
ax2.plot(Climate.index, Climate['relative_temp'], color = 'red')
ax2.set_ylabel('Relative Temperature (Celsius)', color = 'red')
plt.show()

# %% [markdown]
# # More interative
# tick_params

# %%
fig, ax = plt.subplots()
ax.plot(Climate.index, Climate['co2'], color = 'blue')
ax.set_xlabel('Time')
ax.set_ylabel('CO2 (ppm)', color = 'blue')
ax.tick_params('y', colors = 'blue')

#  Creating a twin
ax2 = ax.twinx()
ax2.plot(Climate.index, Climate['relative_temp'], color = 'red')
ax2.set_ylabel('Relative Temperature (Celsius)', color = 'red')
ax2.tick_params('y', colors = 'red')
plt.show()

# %% [markdown]
# # A function that plots time series

# %%
def plot_timeseries(axes, x, y, color, xlabel, ylabel):
    axes.plot(x, y, color = color)
    axes.set_xlabel(xlabel)
    axes.set_ylabel(ylabel, color = color)
    axes.tick_params('y', colors = color)

# %%
fig, ax = plt.subplots()
plot_timeseries(ax, Climate.index, Climate['co2'], 'blue', 'Time', 'CO2 (ppm)')

ax2 = ax.twinx()
plot_timeseries(ax2, Climate.index, Climate['relative_temp'], 'red', 'Time', 'Relative Temperature (Celsius)')
plt.show()

# %%
import pandas as pd
import plotly.graph_objects as go
from plotly.subplots import make_subplots

df = pd.DataFrame({
    'Date': pd.date_range('2022-01-01', periods=10, freq='D'),
    'Sales': [1000, 2000, 3000, 4000, 5000, 6000, 7000, 8000, 9000, 10000],
    'Profit': [100, 200, 300, 400, 500, 600, 700, 800, 900, 1000]
})

df.set_index('Date', inplace=True)

print(df)
# Out:
#             Sales  Profit
# Date
# 2022-01-01   1000     100
# 2022-01-02   2000     200
# 2022-01-03   3000     300
# 2022-01-04   4000     400
# 2022-01-05   5000     500
# 2022-01-06   6000     600
# 2022-01-07   7000     700
# 2022-01-08   8000     800
# 2022-01-09   9000     900
# 2022-01-10  10000    1000

# %%
fig = make_subplots(specs=[[{"secondary_y": True}]])
fig.add_trace(go.Scatter(x=df.index, y=df['Sales'], name='Sales'), secondary_y=False)
fig.add_trace(go.Scatter(x=df.index, y=df['Profit'], name='Profit'), secondary_y=True)
fig.update_layout(title='Sales and Profit by Date')
fig.update_xaxes(title_text='Date')
fig.update_yaxes(title_text='Sales', secondary_y=False)
fig.update_yaxes(title_text='Profit', secondary_y=True)
fig.show()
# Out:
# <div>                            <div id="37dd669c-55e4-44e3-92d1-352d087a6175" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("37dd669c-55e4-44e3-92d1-352d087a6175")) {                    Plotly.newPlot(                        "37dd669c-55e4-44e3-92d1-352d087a6175",                        [{"name":"Sales","x":["2022-01-01T00:00:00","2022-01-02T00:00:00","2022-01-03T00:00:00","2022-01-04T00:00:00","2022-01-05T00:00:00","2022-01-06T00:00:00","2022-01-07T00:00:00","2022-01-08T00:00:00","2022-01-09T00:00:00","2022-01-10T00:00:00"],"y":[1000,2000,3000,4000,5000,6000,7000,8000,9000,10000],"type":"scatter","xaxis":"x","yaxis":"y"},{"name":"Profit","x":["2022-01-01T00:00:00","2022-01-02T00:00:00","2022-01-03T00:00:00","2022-01-04T00:00:00","2022-01-05T00:00:00","2022-01-06T00:00:00","2022-01-07T00:00:00","2022-01-08T00:00:00","2022-01-09T00:00:00","2022-01-10T00:00:00"],"y":[100,200,300,400,500,600,700,800,900,1000],"type":"scatter","xaxis":"x","yaxis":"y2"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar": ...

# %%
fig = make_subplots(specs=[[{"secondary_y": True}]])
fig.add_trace(go.Scatter(x= Climate.index, y= Climate['co2'], name='CO2'), secondary_y=False)
fig.add_trace(go.Scatter(x= Climate.index, y= Climate['relative_temp'], name= ' Temp (Celsius)'), secondary_y=True)
fig.update_layout(title='CO2 and Temperature Over The Years')
fig.update_xaxes(title_text='Year')
fig.update_yaxes(title_text='CO2', secondary_y=False)
fig.update_yaxes(title_text='Temp', secondary_y=True)
fig.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/41/5qy4wjjs2fv7xjzw2hgjt1vc0000gn/T/ipykernel_40183/491788493.py in <module>
# ----> 1 fig = make_subplots(specs=[[{"secondary_y": True}]])
#       2 fig.add_trace(go.Scatter(x= Climate.index, y= Climate['co2'], name='CO2'), secondary_y=False)
#       3 fig.add_trace(go.Scatter(x= Climate.index, y= Climate['relative_temp'], name= ' Temp (Celsius)'), secondary_y=True)
#       4 fig.update_layout(title='CO2 and Temperature Over The Years')
#       5 fig.update_xaxes(title_text='Year')
#
# NameError: name 'make_subplots' is not defined

# %% [markdown]
# # Annotating time-series data

# %%
fig, ax = plt.subplots()
plot_timeseries(ax, Climate.index, Climate['co2'], 'blue', 'Time', 'CO2 (ppm)')

ax2 = ax.twinx()
plot_timeseries(ax2, Climate.index, Climate['relative_temp'], 'red', 'Time', 'Relative Temperature (Celsius)')
ax2.annotate(">1 degree", xy = (pd.Timestamp("2015-10-06"), 1))
plt.show()

# %% [markdown]
# # It is a mess

# %%
fig, ax = plt.subplots()
plot_timeseries(ax, Climate.index, Climate['co2'], 'blue', 'Time', 'CO2 (ppm)')

ax2 = ax.twinx()
plot_timeseries(ax2, Climate.index, Climate['relative_temp'], 'red', 'Time', 'Relative Temperature (Celsius)')
ax2.annotate(">1 degree", xy = (pd.Timestamp("2015-10-06"), 1),
            xytext = (pd.Timestamp('2008-10-06'), -0.2))
plt.show()

# %% [markdown]
# Now it is not showing which data is indicating

# %%
# Adding ana arrow
fig, ax = plt.subplots()
plot_timeseries(ax, Climate.index, Climate['co2'], 'blue', 'Time', 'CO2 (ppm)')

ax2 = ax.twinx()
plot_timeseries(ax2, Climate.index, Climate['relative_temp'], 'red', 'Time', 'Relative Temperature (Celsius)')
ax2.annotate(">1 degree", xy = (pd.Timestamp("2015-10-06"), 1),
            xytext = (pd.Timestamp('2008-10-06'), -0.2),
            arrowprops = {})
plt.show()

# %%
fig, ax = plt.subplots()
plot_timeseries(ax, Climate.index, Climate['co2'], 'blue', 'Time', 'CO2 (ppm)')

ax2 = ax.twinx()
plot_timeseries(ax2, Climate.index, Climate['relative_temp'], 'red', 'Time', 'Relative Temperature (Celsius)')
ax2.annotate(">1 degree", xy = (pd.Timestamp("2015-10-06"), 1),
            xytext = (pd.Timestamp('2008-10-06'), -0.2),
            arrowprops = {'arrowstyle':'->', 'color':'gray'})
plt.show()

# %%
fig, ax = plt.subplots()
ax.plot(Climate.index, Climate['relative_temp'])
ax.annotate('>1 degree', xy = (pd.Timestamp('2015-10-06'), 1))
plt.show()

# %% [markdown]
# # Quantitative comparisons

# %%
medals = pd.read_csv('/Users/mishudhar/Downloads/medals_by_country_2016.csv', index_col = 0)
medals.head()
# Out:
#                Bronze  Gold  Silver
# United States      67   137      52
# Germany            67    47      43
# Great Britain      26    64      55
# Russia             35    50      28
# China              35    44      30

# %%
fig, ax = plt.subplots()
ax.bar(medals.index, medals['Gold'])
plt.show()

# %% [markdown]
# # Names are overlapping

# %%
fig, ax = plt.subplots()
ax.bar(medals.index, medals['Gold'])
ax.set_xticklabels(medals.index, rotation = 90)
ax.set_ylabel('Number of Medals')
plt.show()
# Out:
# /var/folders/41/5qy4wjjs2fv7xjzw2hgjt1vc0000gn/T/ipykernel_1916/3372866984.py:3: UserWarning:
#
# FixedFormatter should only be used together with FixedLocator

# %%
fig = px.bar(medals, x = medals.index, y = 'Gold', color = medals.index)
fig.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/41/5qy4wjjs2fv7xjzw2hgjt1vc0000gn/T/ipykernel_40183/3233694788.py in <module>
# ----> 1 fig = px.bar(medals, x = medals.index, y = 'Gold', color = medals.index)
#       2 fig.show()
#
# NameError: name 'medals' is not defined

# %% [markdown]
# # Stacked bar charts

# %%
fig, ax = plt.subplots()
ax.bar(medals.index, medals['Gold'])
ax.bar(medals.index, medals['Silver'], bottom = medals['Gold'])
ax.bar(medals.index, medals['Bronze'], bottom = medals['Gold'] + medals['Silver'])
ax.set_xticklabels(medals.index, rotation = 90)
ax.set_ylabel('Number of medals')
ax.legend()
plt.show()
# Out:
# /var/folders/41/5qy4wjjs2fv7xjzw2hgjt1vc0000gn/T/ipykernel_1916/3083545073.py:5: UserWarning:
#
# FixedFormatter should only be used together with FixedLocator
#
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
fig, ax = plt.subplots()
ax.bar(medals.index, medals['Gold'], label = 'Gold')
ax.bar(medals.index, medals['Silver'], bottom = medals['Gold'], label = 'Silver')
ax.bar(medals.index, medals['Bronze'], bottom = medals['Gold'] + medals['Silver'], label = 'Bronze')
ax.set_xticklabels(medals.index, rotation = 90)
ax.set_ylabel('Number of medals')
ax.legend()
plt.show()
# Out:
# /var/folders/41/5qy4wjjs2fv7xjzw2hgjt1vc0000gn/T/ipykernel_1916/2531303851.py:5: UserWarning:
#
# FixedFormatter should only be used together with FixedLocator

# %%
import plotly.graph_objects as go
traces = []
for column in ['Gold', 'Bronze', 'Silver']:
    trace = go.Bar(x = medals.index, y = medals[column], name = column)
    traces.append(trace)
layout = go.Layout(title = 'Medals by Countries', barmode = 'stack')
fig = go.Figure(data = traces, layout = layout)
fig.show()
# Out:
# <div>                            <div id="2164634e-3895-4e8c-8546-d83f80b1e7eb" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("2164634e-3895-4e8c-8546-d83f80b1e7eb")) {                    Plotly.newPlot(                        "2164634e-3895-4e8c-8546-d83f80b1e7eb",                        [{"name":"Gold","x":["United States","Germany","Great Britain","Russia","China","France","Australia","Italy","Canada","Japan"],"y":[137,47,64,50,44,20,23,8,4,17],"type":"bar"},{"name":"Bronze","x":["United States","Germany","Great Britain","Russia","China","France","Australia","Italy","Canada","Japan"],"y":[67,67,26,35,35,21,25,24,61,34],"type":"bar"},{"name":"Silver","x":["United States","Germany","Great Britain","Russia","China","France","Australia","Italy","Canada","Japan"],"y":[52,43,55,28,30,55,34,38,4,13],"type":"bar"}],                        {"barmode":"stack","title":{"text":"Medals by Countries"},"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color" ...

# %% [markdown]
# # Quantitative Comparison

# %%
summer_olympic = pd.read_csv('/Users/mishudhar/Downloads/matplotlib and statistics course/summer2016.csv')
summer_olympic.head()
# Out:
#    Unnamed: 0   ID                         Name Sex   Age  Height  Weight  \
# 0         158   62            Giovanni Abagnale   M  21.0   198.0    90.0
# 1         161   65            Patimat Abakarova   F  21.0   165.0    49.0
# 2         175   73                    Luc Abalo   M  31.0   182.0    86.0
# 3         450  250         Saeid Morad Abdevali   M  26.0   170.0    80.0
# 4         794  455  Denis Mikhaylovich Ablyazin   M  24.0   161.0    62.0
#
#          Team  NOC        Games  Year  Season            City       Sport  \
# 0       Italy  ITA  2016 Summer  2016  Summer  Rio de Janeiro      Rowing
# 1  Azerbaijan  AZE  2016 Summer  2016  Summer  Rio de Janeiro   Taekwondo
# 2      France  FRA  2016 Summer  2016  Summer  Rio de Janeiro    Handball
# 3        Iran  IRI  2016 Summer  2016  Summer  Rio de Janeiro   Wrestling
# 4      Russia  RUS  2016 Summer  2016  Summer  Rio de Janeiro  Gymnastics
#
#                                        Event   Medal
# 0                 Rowing Men's Coxless Pairs  Bronze
# 1                Taekwondo Women's Flyweight  Bronze
# 2                    Handball Men's Handball  Silver
# 3  Wrestling Men's Middleweight, Greco-Roman  Bronze
# 4           Gymnastics Men's Team All-Around  Silver

# %%
mens_rowing = summer_olympic[summer_olympic['Sport'] == 'Rowing']

# %%
mens_rowing.head()
# Out:
#     Unnamed: 0    ID                 Name Sex   Age  Height  Weight  \
# 0          158    62    Giovanni Abagnale   M  21.0   198.0    90.0
# 10        1228   690   Chantal Achterberg   F  31.0   172.0    72.0
# 52        6598  3691  Anne Dsane Andersen   F  23.0   183.0    86.0
# 78       11648  6346           Jrmie Azou   M  27.0   178.0    71.0
# 89       14103  7612            Carina Br   F  26.0   185.0    75.0
#
#            Team  NOC        Games  Year  Season            City   Sport  \
# 0         Italy  ITA  2016 Summer  2016  Summer  Rio de Janeiro  Rowing
# 10  Netherlands  NED  2016 Summer  2016  Summer  Rio de Janeiro  Rowing
# 52      Denmark  DEN  2016 Summer  2016  Summer  Rio de Janeiro  Rowing
# 78       France  FRA  2016 Summer  2016  Summer  Rio de Janeiro  Rowing
# 89      Germany  GER  2016 Summer  2016  Summer  Rio de Janeiro  Rowing
#
#                                      Event   Medal
# 0               Rowing Men's Coxless Pairs  Bronze
# 10         Rowing Women's Quadruple Sculls  Silver
# 52            Rowing Women's Coxless Pairs  Bronze
# 78  Rowing Men's Lightweight Double Sculls    Gold
# 89         Rowing Women's Quadruple Sculls    Gold

# %%
mens_gymnastics = summer_olympic[summer_olympic['Sport'] == 'Gymnastics']
mens_gymnastics.head()
# Out:
#      Unnamed: 0    ID                         Name Sex   Age  Height  Weight  \
# 4           794   455  Denis Mikhaylovich Ablyazin   M  24.0   161.0    62.0
# 5           796   455  Denis Mikhaylovich Ablyazin   M  24.0   161.0    62.0
# 6           797   455  Denis Mikhaylovich Ablyazin   M  24.0   161.0    62.0
# 122       18577  9829   David Sagitovich Belyavsky   M  24.0   165.0    55.0
# 123       18579  9829   David Sagitovich Belyavsky   M  24.0   165.0    55.0
#
#        Team  NOC        Games  Year  Season            City       Sport  \
# 4    Russia  RUS  2016 Summer  2016  Summer  Rio de Janeiro  Gymnastics
# 5    Russia  RUS  2016 Summer  2016  Summer  Rio de Janeiro  Gymnastics
# 6    Russia  RUS  2016 Summer  2016  Summer  Rio de Janeiro  Gymnastics
# 122  Russia  RUS  2016 Summer  2016  Summer  Rio de Janeiro  Gymnastics
# 123  Russia  RUS  2016 Summer  2016  Summer  Rio de Janeiro  Gymnastics
#
#                                 Event   Medal
# 4    Gymnastics Men's Team All-Around  Silver
# 5        Gymnastics Men's Horse Vault  Silver
# 6              Gymnastics Men's Rings  Bronze
# 122  Gymnastics Men's Team All-Around  Silver
# 123    Gymnastics Men's Parallel Bars  Bronze

# %%
fig, ax = plt.subplots()
ax.bar('Rowing(Olympic)', mens_rowing['Height'].mean())
ax.bar('Gymnastics(Olympic)', mens_gymnastics['Height'].mean())
ax.set_ylabel('Height (cm)')
plt.show()

# %%
fig, ax = plt.subplots()
ax.hist(mens_rowing['Height'], label = 'Rowing')
ax.hist(mens_gymnastics['Height'], label = 'Gymnastics')
ax.set_xlabel('Height (cm)')
ax.set_ylabel('# of observations')
ax.legend()
plt.show()

# %%
fig, ax = plt.subplots()
ax.hist(mens_rowing['Height'], label = 'Rowing', bins = [150, 160, 170, 180, 190, 200, 210])
ax.hist(mens_gymnastics['Height'], label = 'Gymnastics', bins = [150, 160, 170, 180, 190, 200, 210])
ax.set_xlabel('Height (cm)')
ax.set_ylabel('# of observations')
ax.legend()
plt.show()
print('By default binsize is 10')
# Out:
# By default binsize is 10

# %%
fig, ax = plt.subplots()
ax.hist(mens_rowing['Height'], label = 'Rowing', bins = [150, 160, 170, 180, 190, 200, 210], histtype = 'step')
ax.hist(mens_gymnastics['Height'], label = 'Gymnastics', bins = [150, 160, 170, 180, 190, 200, 210], histtype = 'step')
ax.set_xlabel('Height (cm)')
ax.set_ylabel('# of observations')
ax.legend()
plt.show()

# %%
import plotly.express as px

fig = px.histogram(mens_rowing, x = 'Height', nbins = 20, opacity = 0.5, barmode = 'overlay')
fig.add_histogram( x = mens_gymnastics['Height'])

fig.show()
# Out:
# <div>                            <div id="5a16f165-6919-4686-91e8-a4f9d6230651" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("5a16f165-6919-4686-91e8-a4f9d6230651")) {                    Plotly.newPlot(                        "5a16f165-6919-4686-91e8-a4f9d6230651",                        [{"alignmentgroup":"True","bingroup":"x","hovertemplate":"Height=%{x}<br>count=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","opacity":0.5,"pattern":{"shape":""}},"name":"","nbinsx":20,"offsetgroup":"","orientation":"v","showlegend":false,"x":[198.0,172.0,183.0,178.0,185.0,183.0,188.0,183.0,187.0,179.0,207.0,186.0,170.0,186.0,189.0,190.0,193.0,184.0,187.0,175.0,181.0,188.0,182.0,180.0,186.0,187.0,188.0,172.0,184.0,200.0,150.0,200.0,180.0,194.0,196.0,178.0,180.0,198.0,191.0,173.0,190.0,177.0,185.0,195.0,183.0,198.0,179.0,190.0,193.0,187.0,173.0,197.0,194.0,172.0,193.0,182.0,178.0,194.0,184.0,182.0,165.0,193.0,183.0,196.0,177.0,196.0,194.0,182.0,176.0,183.0,183.0,191.0,196.0,188.0,190.0,199.0,175.0,189.0,193.0,195.0,189.0,195.0,195.0,183.0,195.0,180.0,165.0,191.0,172.0,177.0,186.0,173.0,174.0,190.0,180.0,185.0,187.0,190.0,198.0,187.0,197.0,188.0,195.0,202.0,195.0,198.0,169.0,202.0,180.0,173.0,191.0,195.0,190.0,186.0,178.0,197.0,183.0,188.0,187.0,163.0,184.0,174.0,181.0,183.0,181.0,180.0,185.0,199.0,194.0,173.0,193.0,183.0,192.0,193.0,199.0,176.0,197.0,195.0,170.0,199.0,173.0,201.0,184.0,182.0],"xaxis":"x","yaxis":"y","type":"histogram"},{"x":[161.0,161.0,161.0,165.0,165.0,143.0,143.0,143.0,143.0,143.0,163.0,157.0,148.0,164.0,152.0,152.0,170.0,162.0,157.0,157.0,172.0,170.0,170.0,163.0,162.0,151.0,169.0,151.0,162.0,162.0,162.0,170.0,166.0,161.0,161.0,164.0,157.0,157.0,157.0,155.0,167.0,143.0,162.0,162.0,184.0,156.0,160.0,170.0,148.0,166.0,152.0,146.0,160.0,160.0,161.0,161.0,140.0,156.0,167.0,167.0,167.0,166.0,159.0,162.0,156.0,173.0],"type":"histogram"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0 ...

# %% [markdown]
# # Adding error bars in plot

# %%
fig, ax = plt.subplots()
ax.bar('Rowing', mens_rowing['Height'].mean(),
      yerr = mens_rowing['Height'].std())
ax.bar('Gymnastics', mens_gymnastics['Height'].mean(),
      yerr = mens_gymnastics['Height'].std())
ax.set_xlabel('Height (cm)')
plt.show()

# %%
Seat_weather = d_1

# %%
Seat_weather.head()
# Out:
#        STATION                 NAME  DATE  MLY-CLDD-BASE45  MLY-CLDD-BASE50  \
# 0  USC00456295  PALMER 3 ESE, WA US     1             13.0              1.0
# 1  USC00456295  PALMER 3 ESE, WA US     2             23.0              3.0
# 2  USC00456295  PALMER 3 ESE, WA US     3             50.0             11.0
# 3  USC00456295  PALMER 3 ESE, WA US     4            108.0             40.0
# 4  USC00456295  PALMER 3 ESE, WA US     5            255.0            130.0
#
#    MLY-CLDD-BASE55  MLY-CLDD-BASE57  MLY-CLDD-BASE60  MLY-CLDD-BASE70  \
# 0          -7777.0              0.0              0.0              0.0
# 1          -7777.0          -7777.0              0.0              0.0
# 2              1.0          -7777.0          -7777.0              0.0
# 3             12.0              7.0              3.0          -7777.0
# 4             56.0             38.0             19.0              1.0
#
#    MLY-CLDD-BASE72  ...  MLY-TMIN-AVGNDS-LSTH060  MLY-TMIN-AVGNDS-LSTH070  \
# 0              0.0  ...                    310.0                    310.0
# 1              0.0  ...                    280.0                    280.0
# 2              0.0  ...                    310.0                    310.0
# 3              0.0  ...                    300.0                    300.0
# 4          -7777.0  ...                    310.0                    310.0
#
#    MLY-TMIN-NORMAL  MLY-TMIN-PRBOCC-LSTH016  MLY-TMIN-PRBOCC-LSTH020  \
# 0             34.0                    168.0                    327.0
# 1             33.9                    132.0                    275.0
# 2             35.9                      5.0                     47.0
# 3             38.3                      0.0                      0.0
# 4             43.5                      0.0                      0.0
#
#    MLY-TMIN-PRBOCC-LSTH024  MLY-TMIN-PRBOCC-LSTH028  MLY-TMIN-PRBOCC-LSTH032  \
# 0                    615.0                    877.0                    987.0
# 1                    515.0                    800.0                    963.0
# 2                    111.0                    393.0                    848.0
# 3                      5.0                    123.0                    571.0
# 4                      0.0                      0.0                     83.0
#
#    MLY-TMIN-PRBOCC-LSTH036  MLY-TMIN-STDDEV
# 0                   1000.0              2.8
# 1                   1000.0              3.1
# 2                   1000.0              2.1
# 3                    978.0              2.0
# 4                    610.0              2.0
#
# [5 rows x 80 columns]

# %%
Austin_weather.head()
# Out:
#        STATION                                           NAME  DATE  \
# 0  USW00013904  AUSTIN BERGSTROM INTERNATIONAL AIRPORT, TX US     1
# 1  USW00013904  AUSTIN BERGSTROM INTERNATIONAL AIRPORT, TX US     2
# 2  USW00013904  AUSTIN BERGSTROM INTERNATIONAL AIRPORT, TX US     3
# 3  USW00013904  AUSTIN BERGSTROM INTERNATIONAL AIRPORT, TX US     4
# 4  USW00013904  AUSTIN BERGSTROM INTERNATIONAL AIRPORT, TX US     5
#
#    MLY-CLDD-BASE45  MLY-CLDD-BASE50  MLY-CLDD-BASE55  MLY-CLDD-BASE57  \
# 0              190              103               50               35
# 1              228              132               68               49
# 2              446              306              185              146
# 3              668              519              373              318
# 4              936              781              626              564
#
#    MLY-CLDD-BASE60  MLY-CLDD-BASE70  MLY-CLDD-BASE72  ...  \
# 0               18                1            -7777  ...
# 1               29                3                1  ...
# 2               98               13                6  ...
# 3              240               53               32  ...
# 4              471              181              134  ...
#
#    MLY-TMIN-AVGNDS-LSTH060  MLY-TMIN-AVGNDS-LSTH070  MLY-TMIN-NORMAL  \
# 0                      302                      310             36.3
# 1                      264                      280             39.4
# 2                      270                      308             46.6
# 3                      193                      287             54.7
# 4                       89                      250             63.7
#
#    MLY-TMIN-PRBOCC-LSTH016  MLY-TMIN-PRBOCC-LSTH020  MLY-TMIN-PRBOCC-LSTH024  \
# 0                      298                      570                      839
# 1                      103                      327                      614
# 2                       10                       73                      242
# 3                        0                        0                        0
# 4                        0                        0                        0
#
#    MLY-TMIN-PRBOCC-LSTH028  MLY-TMIN-PRBOCC-LSTH032  MLY-TMIN-PRBOCC-LSTH036  \
# 0                      967                      997                     1000
# 1                      867                      973                      999
# 2                      494                      761                      928
# 3                       48                      189                      453
# 4                        0                        0                        0
#
#    MLY-TMIN-STDDEV
# 0              2.9
# 1              3.2
# 2              3.6
# 3              4.1
# 4              2.5
#
# [5 rows x 67 columns]

# %%
fig, ax = plt.subplots()
ax.errorbar(Seat_weather['Month'], Seat_weather['MLY-TAVG-NORMAL'],
           yerr = Seat_weather['MLY-TAVG-STDDEV'])
ax.errorbar(Austin_weather['Month'], Austin_weather['MLY-TAVG-NORMAL'],
           yerr = Austin_weather['MLY-TAVG-STDDEV'])
ax.set_ylabel('Temperature (Farenhit)')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /opt/anaconda3/lib/python3.9/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3628             try:
# -> 3629                 return self._engine.get_loc(casted_key)
#    3630             except KeyError as err:
#
# /opt/anaconda3/lib/python3.9/site-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# /opt/anaconda3/lib/python3.9/site-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Month'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# /var/folders/41/5qy4wjjs2fv7xjzw2hgjt1vc0000gn/T/ipykernel_40183/1670852792.py in <module>
#       1 fig, ax = plt.subplots()
# ----> 2 ax.errorbar(Seat_weather['Month'], Seat_weather['MLY-TAVG-NORMAL'],
#       3            yerr = Seat_weather['MLY-TAVG-STDDEV'])
#       4 ax.errorbar(Austin_weather['Month'], Austin_weather['MLY-TAVG-NORMAL'],
#       5            yerr = Austin_weather['MLY-TAVG-STDDEV'])
#
# /opt/anaconda3/lib/python3.9/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    3503             if self.columns.nlevels > 1:
#    3504                 return self._getitem_multilevel(key)
# -> 3505             indexer = self.columns.get_loc(key)
#    3506             if is_integer(indexer):
#    3507                 indexer = [indexer]
#
# /opt/anaconda3/lib/python3.9/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3629                 return self._engine.get_loc(casted_key)
#    3630             except KeyError as err:
# -> 3631                 raise KeyError(key) from err
#    3632             except TypeError:
#    3633                 # If we have a listlike key, _check_indexing_error will raise
#
# KeyError: 'Month'

# %%
fig, ax = plt.subplots()
ax.boxplot([mens_rowing['Height'], mens_gymnastics['Height']])

ax.set_xticklabels(["Rowing", "Gymnastics"])

ax.set_ylabel('Height (cm)')

plt.show()

# %%
fig, ax = plt.subplots()
ax.scatter(Climate['co2'], Climate['relative_temp'])
ax.set_xlabel('CO2 (ppm)')
ax.set_ylabel('Relative temperature (celsius)')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/41/5qy4wjjs2fv7xjzw2hgjt1vc0000gn/T/ipykernel_40183/4184235205.py in <module>
#       1 fig, ax = plt.subplots()
# ----> 2 ax.scatter(Climate['co2'], Climate['relative_temp'])
#       3 ax.set_xlabel('CO2 (ppm)')
#       4 ax.set_ylabel('Relative temperature (celsius)')
#       5 plt.show()
#
# NameError: name 'Climate' is not defined

# %%
Eighties = Climate["1980-01-01":"1989-12-31"]
Eighties.head()
# Out:
#                co2  relative_temp
# date
# 1980-01-06  337.90           0.30
# 1980-02-06  338.34           0.42
# 1980-03-06  340.01           0.29
# 1980-04-06  340.93           0.32
# 1980-05-06  341.48           0.34

# %%
Nineties = Climate["1990-01-01":"1999-12-31"]
Nineties.head()
# Out:
#                co2  relative_temp
# date
# 1990-01-06  353.80           0.41
# 1990-02-06  355.04           0.41
# 1990-03-06  355.73           0.76
# 1990-04-06  356.32           0.55
# 1990-05-06  357.32           0.46

# %%
fig, ax = plt.subplots()
ax.scatter(Eighties['co2'], Eighties['relative_temp'],
          color = 'red', label = 'eighties')
ax.scatter(Nineties['co2'], Nineties['relative_temp'],
           color = 'blue', label = 'nineties')
ax.legend()

ax.set_xlabel("CO2 (ppm)")
ax.set_ylabel("Relative temperature (Celsius)")
plt.show()

# %%
fig, ax = plt.subplots()
ax.scatter(Climate['co2'], Climate['relative_temp'], c = Climate.index)
ax.set_xlabel('CO2 (ppm)')
ax.set_ylabel('Relative temperature (Celsius)')
plt.show()

# %% [markdown]
# # Preparing your plots to share with others

# %%
plt.style.use('ggplot')
fig, ax = plt.subplots()
ax.errorbar(Seat_weather['Month'], Seat_weather['MLY-TAVG-NORMAL'],
           yerr = Seat_weather['MLY-TAVG-STDDEV'])
ax.errorbar(Austin_weather['Month'], Austin_weather['MLY-TAVG-NORMAL'],
           yerr = Austin_weather['MLY-TAVG-STDDEV'])
ax.set_ylabel('Temperature (Farenhit)')
plt.show()

# %%
plt.style.use('seaborn-colorblind')
fig, ax = plt.subplots()
ax.errorbar(Seat_weather['Month'], Seat_weather['MLY-TAVG-NORMAL'],
           yerr = Seat_weather['MLY-TAVG-STDDEV'])
ax.errorbar(Austin_weather['Month'], Austin_weather['MLY-TAVG-NORMAL'],
           yerr = Austin_weather['MLY-TAVG-STDDEV'])
ax.set_ylabel('Temperature (Farenhit)')
plt.show()

# %%
plt.style.use('tableau-colorblind10')
fig, ax = plt.subplots()
ax.errorbar(Seat_weather['Month'], Seat_weather['MLY-TAVG-NORMAL'],
           yerr = Seat_weather['MLY-TAVG-STDDEV'])
ax.errorbar(Austin_weather['Month'], Austin_weather['MLY-TAVG-NORMAL'],
           yerr = Austin_weather['MLY-TAVG-STDDEV'])
ax.set_ylabel('Temperature (Farenhit)')
plt.show()

# %% [markdown]
# various styles are such as Solarize_Light2, grayscale(for black and white printer)

# %% [markdown]
# # Saving Figures

# %%
fig, ax = plt.subplots()
ax.bar(medals.index, medals['Gold'])
ax.set_xticklabels(medals.index, rotation = 90)
ax.set_ylabel('Number of Medals')
#ax.legend()
fig.savefig('gold_medals.png')
#fig.savefig('gold_medals.jpg') for JPG file
# Out:
# /var/folders/41/5qy4wjjs2fv7xjzw2hgjt1vc0000gn/T/ipykernel_1916/4100006053.py:3: UserWarning:
#
# FixedFormatter should only be used together with FixedLocator

# %%
fig, ax = plt.subplots()
ax.bar(medals.index, medals['Gold'])
ax.set_xticklabels(medals.index, rotation = 90)
ax.set_ylabel('Number of Medals')
#ax.legend()
#fig.savefig('gold_medals.png')
fig.savefig('gold_medals.jpg', quality = 50)
# Out:
# /var/folders/41/5qy4wjjs2fv7xjzw2hgjt1vc0000gn/T/ipykernel_1916/1027642790.py:3: UserWarning:
#
# FixedFormatter should only be used together with FixedLocator
#
# /var/folders/41/5qy4wjjs2fv7xjzw2hgjt1vc0000gn/T/ipykernel_1916/1027642790.py:7: MatplotlibDeprecationWarning:
#
# savefig() got unexpected keyword argument "quality" which is no longer supported as of 3.3 and will become an error in 3.6

# %%
fig, ax = plt.subplots()
ax.bar(medals.index, medals['Gold'])
ax.set_xticklabels(medals.index, rotation = 90)
ax.set_ylabel('Number of Medals')
#ax.legend()
#fig.savefig('gold_medals.png')
fig.savefig('gold_medals.svg')
# Out:
# /var/folders/41/5qy4wjjs2fv7xjzw2hgjt1vc0000gn/T/ipykernel_1916/3652038347.py:3: UserWarning:
#
# FixedFormatter should only be used together with FixedLocator

# %%
fig, ax = plt.subplots()
ax.bar(medals.index, medals['Gold'])
ax.set_xticklabels(medals.index, rotation = 90)
ax.set_ylabel('Number of Medals')
#ax.legend()
#fig.savefig('gold_medals.png')
fig.savefig('gold_medals.png', dpi = 300) # dot per inch
# Out:
# /var/folders/41/5qy4wjjs2fv7xjzw2hgjt1vc0000gn/T/ipykernel_1916/1708306566.py:3: UserWarning:
#
# FixedFormatter should only be used together with FixedLocator

# %%
fig, ax = plt.subplots()
ax.bar(medals.index, medals['Gold'])
ax.set_xticklabels(medals.index, rotation = 90)
ax.set_ylabel('Number of Medals')
#ax.legend()
#fig.savefig('gold_medals.png
fig.set_size_inches([5,3] # First number is the width and second number is the height
fig.savefig('gold_medals.png', dpi = 300)
# Out:
# /var/folders/41/5qy4wjjs2fv7xjzw2hgjt1vc0000gn/T/ipykernel_1916/3397731020.py:3: UserWarning:
#
# FixedFormatter should only be used together with FixedLocator

# %%
ls
# Out:
# Data Visualisation in Matplotlib.ipynb
# Introduction to Statistics.ipynb
# JOINING(MERGING) data in pandas.ipynb
# Joining data.ipynb
# Pivot.ipynb
# Project- the guthub  history of the Scala Language.ipynb
# Python-3.ipynb
# Untitled Folder/
# WorldBank_GDP.csv
# WorldBank_POP.csv
# data.csv
# gold_medals.jpg
# gold_medals.png
# gold_medals.svg

# %% [markdown]
# # Automating figures from Data
# # Why automating?
# 1. Ease and speed
# 2. Flexibility
# 3. Robustness
# 4. Reproducibility

# %%
summer_olympic.head()
# Out:
#    Unnamed: 0   ID                         Name Sex   Age  Height  Weight  \
# 0         158   62            Giovanni Abagnale   M  21.0   198.0    90.0
# 1         161   65            Patimat Abakarova   F  21.0   165.0    49.0
# 2         175   73                    Luc Abalo   M  31.0   182.0    86.0
# 3         450  250         Saeid Morad Abdevali   M  26.0   170.0    80.0
# 4         794  455  Denis Mikhaylovich Ablyazin   M  24.0   161.0    62.0
#
#          Team  NOC        Games  Year  Season            City       Sport  \
# 0       Italy  ITA  2016 Summer  2016  Summer  Rio de Janeiro      Rowing
# 1  Azerbaijan  AZE  2016 Summer  2016  Summer  Rio de Janeiro   Taekwondo
# 2      France  FRA  2016 Summer  2016  Summer  Rio de Janeiro    Handball
# 3        Iran  IRI  2016 Summer  2016  Summer  Rio de Janeiro   Wrestling
# 4      Russia  RUS  2016 Summer  2016  Summer  Rio de Janeiro  Gymnastics
#
#                                        Event   Medal
# 0                 Rowing Men's Coxless Pairs  Bronze
# 1                Taekwondo Women's Flyweight  Bronze
# 2                    Handball Men's Handball  Silver
# 3  Wrestling Men's Middleweight, Greco-Roman  Bronze
# 4           Gymnastics Men's Team All-Around  Silver

# %%
# Getting the unique values from a column
sports = summer_olympic['Sport'].unique()
sports
# Out:
# array(['Rowing', 'Taekwondo', 'Handball', 'Wrestling', 'Gymnastics',
#        'Swimming', 'Basketball', 'Boxing', 'Volleyball', 'Athletics',
#        'Rugby Sevens', 'Judo', 'Rhythmic Gymnastics', 'Weightlifting',
#        'Equestrianism', 'Badminton', 'Water Polo', 'Football', 'Fencing',
#        'Shooting', 'Sailing', 'Beach Volleyball', 'Canoeing', 'Hockey',
#        'Cycling', 'Tennis', 'Diving', 'Table Tennis', 'Triathlon',
#        'Archery', 'Synchronized Swimming', 'Modern Pentathlon',
#        'Trampolining', 'Golf'], dtype=object)

# %% [markdown]
# # Bar charts for heights of all sports

# %%
fig, ax = plt.subplots()
for sport in sports:
    sport_df = summer_olympic[summer_olympic['Sport'] == sport]# if the value of Sport column is one of this unique column
    ax.bar(sport, sport_df['Height'].mean(),
          yerr = sport_df['Height'].std())
ax.set_ylabel('Height (cm)')
ax.set_xticklabels(sports, rotation = 90)
plt.show()
# Out:
# /var/folders/41/5qy4wjjs2fv7xjzw2hgjt1vc0000gn/T/ipykernel_1916/485833039.py:7: UserWarning:
#
# FixedFormatter should only be used together with FixedLocator

# %%
fig = px.bar(summer_olympic, x = 'Sport', y = summer_olympic['Height'], color = 'Sport')
fig.show()
# Out:
# <div>                            <div id="3ad19033-2436-42d3-8e20-6090648859a1" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("3ad19033-2436-42d3-8e20-6090648859a1")) {                    Plotly.newPlot(                        "3ad19033-2436-42d3-8e20-6090648859a1",                        [{"alignmentgroup":"True","hovertemplate":"Sport=%{x}<br>Height=%{y}<extra></extra>","legendgroup":"Rowing","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Rowing","offsetgroup":"Rowing","orientation":"v","showlegend":true,"textposition":"auto","x":["Rowing","Rowing","Rowing","Rowing","Rowing","Rowing","Rowing","Rowing","Rowing","Rowing","Rowing","Rowing","Rowing","Rowing","Rowing","Rowing","Rowing","Rowing","Rowing","Rowing","Rowing","Rowing","Rowing","Rowing","Rowing","Rowing","Rowing","Rowing","Rowing","Rowing","Rowing","Rowing","Rowing","Rowing","Rowing","Rowing","Rowing","Rowing","Rowing","Rowing","Rowing","Rowing","Rowing","Rowing","Rowing","Rowing","Rowing","Rowing","Rowing","Rowing","Rowing","Rowing","Rowing","Rowing","Rowing","Rowing","Rowing","Rowing","Rowing","Rowing","Rowing","Rowing","Rowing","Rowing","Rowing","Rowing","Rowing","Rowing","Rowing","Rowing","Rowing","Rowing","Rowing","Rowing","Rowing","Rowing","Rowing","Rowing","Rowing","Rowing","Rowing","Rowing","Rowing","Rowing","Rowing","Rowing","Rowing","Rowing","Rowing","Rowing","Rowing","Rowing","Rowing","Rowing","Rowing","Rowing","Rowing","Rowing","Rowing","Rowing","Rowing","Rowing","Rowing","Rowing","Rowing","Rowing","Rowing","Rowing","Rowing","Rowing","Rowing","Rowing","Rowing","Rowing","Rowing","Rowing","Rowing","Rowing","Rowing","Rowing","Rowing","Rowing","Rowing","Rowing","Rowing","Rowing","Rowing","Rowing","Rowing","Rowing","Rowing","Rowing","Rowing","Rowing","Rowing","Rowing","Rowing","Rowing","Rowing","Rowing","Rowing","Rowing","Rowing","Rowing"],"xaxis":"x","y":[198.0,172.0,183.0,178.0,185.0,183.0,188.0,183.0,187.0,179.0,207.0,186.0,170.0,186.0,189.0,190.0,193.0,184.0,187.0,175.0,181.0,188.0,182.0,180.0,186.0,187.0,188.0,172.0,184.0,200.0,150.0,200.0,180.0,194.0,196.0,178.0,180.0,198.0,191.0,173.0,190.0,177.0,185.0,195.0,183.0,198.0,179.0,190.0,193.0,187.0,173.0,197.0,194.0,172.0,193.0,182.0,178.0,194.0,184.0,182.0,165.0,193.0,183.0,196.0,177.0,196.0,194.0,182.0,176.0,183.0,183.0,191.0,196.0,188.0,190.0,199.0,175.0,189.0,193.0,195.0,189.0,195.0,195.0,183.0,195.0,180.0,165.0,191.0,172.0,177.0,186.0,173.0,174.0,190.0,180.0,185.0,187.0,190.0,198.0,187.0,197.0,188.0,195.0,202.0,195.0,198.0,169.0,202.0,180.0,173.0,191.0,195.0,190.0,186.0,178.0,197.0,183.0,188.0,187.0,163.0,184.0,174.0,181.0,183.0,181.0,180.0,185.0,199.0,194.0,173.0,193.0,183.0,192.0,193.0,199.0,176.0,197.0,195.0,170.0,199.0,173.0,201.0,184.0,182.0],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Sport=%{x}<br>Height=%{y}<extra></extra>","legendgroup":"Taekwondo","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"Taekwondo","offsetgroup":"Taekwondo","orientation":"v","showlegend":true,"textposition":"auto","x":["Taekwondo","Taekwondo","Taekwondo","Taekwondo","Taekwondo","Taekwondo","Taekwondo","Taekwondo","Taekwondo","Taekwondo","Taekwondo","Taekwondo","Taekwondo","Taekwondo","Taekwondo","Taekwondo","Taekwondo","Taekwondo","Taekwondo","Taekwondo","Taekwondo","Taekwondo","Taekwondo","Taekwondo","Taekwondo","Taekwondo","Taekwondo","Taekwondo","Taekwondo","Taekwondo","Taekwondo","Taekwondo"],"xaxis":"x","y":[165.0,178.0,207.0,185.0,197.0,172.0,176.0,186.0,185.0,173.0,178.0,176.0,185.0,176.0,200.0,190.0,156.0,164.0,182.0,183.0,174.0,191.0,176.0,182.0,199.0,183.0,190.0,173.0,182.0,173.0,188.0,188.0],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Sport=%{x}<br>Height=%{y}<extra></extra>","legendgroup":"Handball","ma ...

# %%
summer_olympic.columns
# Out:
# Index(['Unnamed: 0', 'ID', 'Name', 'Sex', 'Age', 'Height', 'Weight', 'Team',
#        'NOC', 'Games', 'Year', 'Season', 'City', 'Sport', 'Event', 'Medal'],
#       dtype='object')

# %% [markdown]
# # An alternative approach by using plotly

# %%
alternative = summer_olympic.groupby(['Sport']).agg({'Height':'mean'}).reset_index()
alternative.head()
# Out:
#               Sport      Height
# 0           Archery  173.083333
# 1         Athletics  177.377660
# 2         Badminton  175.260870
# 3        Basketball  193.138889
# 4  Beach Volleyball  190.000000

# %%
fig = px.bar(data_frame = alternative, x = 'Sport', y = 'Height', color = 'Sport')
fig.show()
# Out:
# <div>                            <div id="9ec5432a-6bec-4404-9883-5b6181b98bda" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("9ec5432a-6bec-4404-9883-5b6181b98bda")) {                    Plotly.newPlot(                        "9ec5432a-6bec-4404-9883-5b6181b98bda",                        [{"alignmentgroup":"True","hovertemplate":"Sport=%{x}<br>Height=%{y}<extra></extra>","legendgroup":"Archery","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Archery","offsetgroup":"Archery","orientation":"v","showlegend":true,"textposition":"auto","x":["Archery"],"xaxis":"x","y":[173.08333333333334],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Sport=%{x}<br>Height=%{y}<extra></extra>","legendgroup":"Athletics","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"Athletics","offsetgroup":"Athletics","orientation":"v","showlegend":true,"textposition":"auto","x":["Athletics"],"xaxis":"x","y":[177.37765957446808],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Sport=%{x}<br>Height=%{y}<extra></extra>","legendgroup":"Badminton","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"Badminton","offsetgroup":"Badminton","orientation":"v","showlegend":true,"textposition":"auto","x":["Badminton"],"xaxis":"x","y":[175.2608695652174],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Sport=%{x}<br>Height=%{y}<extra></extra>","legendgroup":"Basketball","marker":{"color":"#ab63fa","pattern":{"shape":""}},"name":"Basketball","offsetgroup":"Basketball","orientation":"v","showlegend":true,"textposition":"auto","x":["Basketball"],"xaxis":"x","y":[193.13888888888889],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Sport=%{x}<br>Height=%{y}<extra></extra>","legendgroup":"Beach Volleyball","marker":{"color":"#FFA15A","pattern":{"shape":""}},"name":"Beach Volleyball","offsetgroup":"Beach Volleyball","orientation":"v","showlegend":true,"textposition":"auto","x":["Beach Volleyball"],"xaxis":"x","y":[190.0],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Sport=%{x}<br>Height=%{y}<extra></extra>","legendgroup":"Boxing","marker":{"color":"#19d3f3","pattern":{"shape":""}},"name":"Boxing","offsetgroup":"Boxing","orientation":"v","showlegend":true,"textposition":"auto","x":["Boxing"],"xaxis":"x","y":[175.35294117647058],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Sport=%{x}<br>Height=%{y}<extra></extra>","legendgroup":"Canoeing","marker":{"color":"#FF6692","pattern":{"shape":""}},"name":"Canoeing","offsetgroup":"Canoeing","orientation":"v","showlegend":true,"textposition":"auto","x":["Canoeing"],"xaxis":"x","y":[180.1951219512195],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Sport=%{x}<br>Height=%{y}<extra></extra>","legendgroup":"Cycling","marker":{"color":"#B6E880","pattern":{"shape":""}},"name":"Cycling","offsetgroup":"Cycling","orientation":"v","showlegend":true,"textposition":"auto","x":["Cycling"],"xaxis":"x","y":[175.46428571428572],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Sport=%{x}<br>Height=%{y}<extra></extra>","legendgroup":"Diving","marker":{"color":"#FF97FF","pattern":{"shape":""}},"name":"Diving","offsetgroup":"Diving","orientation":"v","showlegend":true,"textposition":"auto","x":["Diving"],"xaxis":"x","y":[165.11111111111111],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Sport=%{x}<br>Height=%{y}<extra></extra>","legendgroup":"Equestrianism","marker":{"color":"#FECB52","pattern":{"shape":""}},"name":"Equestrianism","offsetgroup":"Equestrianism","orientation":"v","showlegend":true,"textposition":"auto","x":["Equestrianism"],"xaxis":"x","y":[174.53333333333333],"yaxis":"y","type":"bar"},{"alignmentgroup":"T ...

# %% [markdown]
# # To learn more
# visit
# https://matplotlib.org/stable/gallery/index.html
# https://matplotlib.org/stable/gallery/mplot3d/scatter3d.html#sphx-glr-gallery-mplot3d-scatter3d-py
# https://matplotlib.org/stable/tutorials/introductory/images.html
# https://matplotlib.org/stable/api/animation_api.html
# https://scitools.org.uk/cartopy/docs/latest/getting_started/index.html #for Geospatial data
